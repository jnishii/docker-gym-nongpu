# %%
import gym
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('Breakout-v0')
env.reset()
for _ in range(1000):
    plt.imshow(env.render(mode='rgb_array'))
    display.clear_output(wait=True)
    display.display(plt.gcf())
    env.step(env.action_space.sample())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-82c4270efd5b> in <module>()
#       7 env.reset()
#       8 for _ in range(1000):
# ----> 9     plt.imshow(env.render(mode='rgb_array'))
#      10     display.clear_output(wait=True)
#      11     display.display(plt.gcf())
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5485                               resample=resample, **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in set_data(self, A)
#     659             # making reliable interpretation impossible.
#     660             high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
# --> 661             if self._A.min() < 0 or high < self._A.max():
#     662                 _log.warning(
#     663                     'Clipping input data to the valid range for imshow with '
#
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py in min(self, axis, out, fill_value, keepdims)
#    5586         if out is None:
#    5587             result = self.filled(fill_value).min(
# -> 5588                 axis=axis, out=out, **kwargs).view(type(self))
#    5589             if result.ndim:
#    5590                 # Set the mask
#
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py in __array_finalize__(self, obj)
#    2932         """
#    2933         # Get main attributes.
# -> 2934         self._update_from(obj)
#    2935
#    2936         # We have to decide how to initialize self.mask, based on
#
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py in _update_from(self, obj)
#    2911         # We need to copy the _basedict to avoid backward propagation
#    2912         _optinfo = {}
# -> 2913         _optinfo.update(getattr(obj, '_optinfo', {}))
#    2914         _optinfo.update(getattr(obj, '_basedict', {}))
#    2915         if not isinstance(obj, MaskedArray):
#
# KeyboardInterrupt:
